# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/tv/top_rated?api_key=7ff9928e01325480ca86fddb66fa93d7')
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/7BzmK4MWc0cj4hCxwWURt6TS6UR.jpg',
#    'genre_ids': [16, 10765, 10759, 35],
#    'id': 131378,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Adventure Time: Fionna & Cake',
#    'overview': 'Fionna and Cake – with the help of the former Ice King, Simon Petrikov - embark on a multiverse-hopping adventure and journey of self-discovery. All the while a powerful new antagonist determined to track them down and erase them from existence, lurks in the shadows.',
#    'popularity': 35.818,
#    'poster_path': '/fi1b6U1kp73xheECzqwzMn8u3mX.jpg',
#    'first_air_date': '2023-08-31',
#    'name': 'Adventure Time: Fionna & Cake',
#    'vote_average': 8.995,
#    'vote_count': 203},
#   {'adult': False,
#    'backdrop_path': '/gc8PfyTqzqltKPW3X0cIVUGmagz.jpg',
#    'genre_ids': [18, 80],
#    'id': 1396,
#    'origin_country': ['US'],
#    'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results']).head()
# Out:
#    adult                     backdrop_path               genre_ids      id  \
# 0  False  /7BzmK4MWc0cj4hCxwWURt6TS6UR.jpg  [16, 10765, 10759, 35]  131378
# 1  False  /gc8PfyTqzqltKPW3X0cIVUGmagz.jpg                [18, 80]    1396
# 2  False  /j67Wi1mzPxPVVybjmaIsvzsqFDH.jpg  [16, 10759, 35, 10765]  240411
# 3  False  /tuCU2yVRM2iZxFkpqlPUyvd6tSu.jpg         [16, 35, 10765]   94954
# 4  False  /sYXLeu5usz6yEz0k00FYvtEdodD.jpg  [16, 10765, 18, 10759]   94605
#
#   origin_country original_language                  original_name  \
# 0           [US]                en  Adventure Time: Fionna & Cake
# 1           [US]                en                   Breaking Bad
# 2           [JP]                ja                          ダンダダン
# 3           [US]                en                   Hazbin Hotel
# 4           [US]                en                         Arcane
#
#                                             overview  popularity  \
# ...

# %%
df=pd.DataFrame(response.json()['results']).head()[['id','original_name','overview','popularity','vote_average','vote_count']]
df
# Out:
#        id                  original_name  \
# 0  131378  Adventure Time: Fionna & Cake
# 1    1396                   Breaking Bad
# 2  240411                          ダンダダン
# 3   94954                   Hazbin Hotel
# 4   94605                         Arcane
#
#                                             overview  popularity  \
# 0  Fionna and Cake – with the help of the former ...      35.818
# 1  Walter White, a New Mexico chemistry teacher, ...     737.144
# 2  In a bet to prove whether ghosts or aliens exi...     189.932
# 3  In attempt to find a non-violent alternative f...     110.633
# 4  Amid the stark discord of twin cities Piltover...     260.242
#
#    vote_average  vote_count
# 0         8.995         203
# 1         8.900       14963
# 2         8.800         386
# 3         8.800        1214
# 4         8.800        4846

# %%
df=pd.DataFrame(response.json()['results'])[['id','original_name','overview','popularity','vote_average','vote_count']]
df
# Out:
#         id                  original_name  \
# 0   131378  Adventure Time: Fionna & Cake
# 1     1396                   Breaking Bad
# 2   240411                          ダンダダン
# 3    94954                   Hazbin Hotel
# 4    94605                         Arcane
# 5   209867                       葬送のフリーレン
# 6      246     Avatar: The Last Airbender
# 7   220542                       薬屋のひとりごと
# 8    37854                          ワンピース
# 9   259666        Nadie nos va a extrañar
# 10   31911     鋼の錬金術師 FULLMETAL ALCHEMIST
# 11   60625                 Rick and Morty
# 12   60059               Better Call Saul
# 13   87108                      Chernobyl
# 14   70785                 Anne with an E
# 15    1429                          進撃の巨人
# 16   42705                         はじめの一歩
# 17   74313                 Blue Planet II
# 18   92685                  The Owl House
# 19   85937                           鬼滅の刃
#
#                                              overview  popularity  \
# ...

# %%
df=pd.DataFrame()

# %%
for i in range(1,429):
    response=requests.get('https://api.themoviedb.org/3/tv/top_rated?api_key=7ff9928e01325480ca86fddb66fa93d7')
    temp_df=pd.DataFrame(response.json()['results'])[['id','original_name','overview','popularity','vote_average','vote_count']]
    df=df[temp_df]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38572\155779466.py in ?()
#       1 for i in range(1,429):
#       2     response=requests.get('https://api.themoviedb.org/3/tv/top_rated?api_key=7ff9928e01325480ca86fddb66fa93d7')
#       3     temp_df=pd.DataFrame(response.json()['results'])[['id','original_name','overview','popularity','vote_average','vote_count']]
# ----> 4     df=df[temp_df]
#
# c:\Users\niraj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4085             return self._getitem_slice(key)
#    4086
#    4087         # Do we have a (boolean) DataFrame?
#    4088         if isinstance(key, DataFrame):
# -> 4089             return self.where(key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
#
# ...
