# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

# %%
x,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
plt.scatter(x,y)

# %%
#lets apply ols
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red')

# %%
#lets apply gradient decent
# and lets assume the starting value for intercept b=0
y_pred=((78.35 * x)+0).reshape(4)

# %%
y_pred
# Out:
# array([-55.81580837,  35.39949674,  -3.48681619,  59.05759577])

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='green',label='b=0')
plt.legend()
plt.show()

# %%
m=78.35
b=0

# %%
loss_slope=-2 * np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# -209.27763408209216

# %%
#lets take learning rate=0.1
lr=0.1
step_size=loss_slope*lr
step_size
# Out:
# -20.927763408209216

# %%
# calculating the new intercept
b=b-step_size
b
# Out:
# 20.927763408209216

# %%
y_pred1=((78.35 * x)+b).reshape(4)
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='black',label='ols')
plt.plot(x,y_pred1,color='purple',label='b={}'.format(b))
plt.plot(x,y_pred,color='black',label='b=0')
plt.legend()

# %%
#iterration 2
loss_slope=-2 * np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# -41.85552681641843

# %%
step_size=loss_slope*lr
step_size
# Out:
# -4.185552681641844

# %%
b=b-step_size
b
# Out:
# 25.11331608985106

# %%
y_pred1=((78.35 * x)+b).reshape(4)
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='black',label='ols')
plt.plot(x,y_pred1,color='purple',label='b={}'.format(b))
plt.plot(x,y_pred,color='black',label='b=0')
plt.legend()

# %%
#iteration 3
loss_slope=-2 * np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# -8.371105363283675

# %%
step_size=loss_slope*lr
step_size
# Out:
# -0.8371105363283675

# %%
b=b-step_size
b
# Out:
# 25.95042662617943

# %%
y_pred1=((78.35 * x)+b).reshape(4)
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='black',label='ols')
plt.plot(x,y_pred1,color='purple',label='b={}'.format(b))
plt.plot(x,y_pred,color='black',label='b=0')
plt.legend()

# %%
#iteration 4
loss_slope=-2 * np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# -1.674221072656735

# %%
step_size=loss_slope*lr
step_size
# Out:
# -0.16742210726567353

# %%
b=b-step_size
b
# Out:
# 26.1178487334451

# %%
y_pred1=((78.35 * x)+b).reshape(4)
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='black',label='ols')
plt.plot(x,y_pred1,color='purple',label='b={}'.format(b))
plt.plot(x,y_pred,color='black',label='b=0')
plt.legend()

# %%
b=-100
m=78.35
lr=0.1

epochs=10

for i in range(100):
    loss_slope=-2*np.sum(y-m*x.ravel()-b)
    b=b-(lr*loss_slope)
    y_pred=m*x+b
    plt.plot(x,y_pred)
plt.scatter(x,y)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [36.82739982]
# 1.9120697681514107

# %%
m=36.82739982

# %%
class GDRegressor:
    def __init__(self,learning_rate,epochs):
        self.m=36.82739982
        self.b=-120
        self.lr=learning_rate
        self.epochs=epochs
        
    def fit(self,x,y):
        #calculate the b using GD
        for i in range(self.epochs):
            loss_slope=-2*np.sum(y-self.m*x.ravel()-self.b)
            self.b=self.b-(self.lr*loss_slope)
            print(loss_slope,self.b)
        
        print(self.b)

# %%
gd=GDRegressor(0.001,100)

# %%
gd.fit(x,y)
# Out:
# -24382.4139536196 -95.6175860463804
# -19505.93116289568 -76.11165488348472
# -15604.744930316545 -60.506909953168176
# -12483.795944253236 -48.02311400891494
# -9987.036755402587 -38.03607725351235
# -7989.629404322069 -30.046447849190283
# -6391.703523457654 -23.65474432573263
# -5113.362818766124 -18.541381506966506
# -4090.6902550129 -14.450691251953605
# -3272.55220401032 -11.178139047943285
# -2618.041763208256 -8.56009728473503
# -2094.4334105666044 -6.465663874168425
# -1675.546728453284 -4.790117145715141
# -1340.437382762627 -3.4496797629525138
# -1072.3499062101016 -2.377329856742412
# -857.8799249680817 -1.5194499317743304
# -686.3039399744652 -0.8331459917998653
# -549.043151979572 -0.28410283982029316
# -439.2345215836576 0.15513168176336445
# -351.3876172669261 0.5065192990302906
# -281.11009381354086 0.7876293928438314
# -224.88807505083255 1.012517467894664
# -179.91046004066624 1.1924279279353303
# -143.92836803253297 1.3363562959678632
# -115.14269442602635 1.4514989903938895
# -92.11415554082105 1.5436131459347107
# -73.69132443265678 1.6173044703673674
# -58.95305954612547 1.6762575299134927
# -47.162447636900495 1.7234199775503933
# -37.72995810952041 1.7611499356599138
# -30.18396648761608 1.7913339021475299
# -24.147173190093252 1.8154810753376232
# -19.317738552074516 1.8347988138896976
# -15.454190841659496 1.850253004731357
# -12.363352673327554 1.8626163574046846
# -9.890682138662306 1.872507039543347
# -7.9125457109296775 1.8804195852542767
# -6.330036568743665 1.8867496218230204
# -5.064029254994859 1.8918136510780152
# -4.05122340399598 1.8958648744820112
# -3.2409787231967897 1.899105853205208
# -2.5927829785575263 1.9016986361837656
# -2.0742263828457723 1.9037728625666113
# -1.6593811062766584 1.9054322436728879
# -1.327504885021412 1.9067597485579093
# -1.0620039080171644 1.9078217524659264
# -0.849603126413566 1.90867135559234
# -0.6796825011312109 1.9093510380934713
# -0.5437460009048252 1.909894784094376
# -0.4349968007236811 1.9103297808950999
# -0.3479974405790536 1.910677778335679
# -0.2783979524633473 1.9109561762881424
# -0.22271836197045047 1.911178894650113
# -0.17817468957644067 1.9113570693396893
# -0.14253975166112198 1.9114996090913505
# -0.11403180132880664 1.9116136408926794
# -0.09122544106314123 1.9117048663337426
# -0.07298035285045046 1.9117778466865931
# -0.058384282280385946 1.9118362309688735
# -0.046707425824266124 1.9118829383946978
# -0.037365940659483954 1.9119203043353572
# -0.029892752527487687 1.9119501970878847
# -0.02391420202221539 1.911974111289907
# -0.019131361617542808 1.9119932426515245
# -0.015305089294027852 1.9120085477408184
# -0.012244071435489445 1.9120207918122538
# -0.00979525714826579 1.912030587069402
# -0.007836205718533051 1.9120384232751206
# -0.006268964574829283 1.9120446922396954
# -0.005015171659913165 1.9120497074113554
# -0.0040121373278765304 1.9120537195486833
# -0.0032097098623644627 1.9120569292585456
# -0.0025677678897260137 1.9120594970264353
# -0.002054214312156688 1.9120615512407475
# -0.001643371449642217 1.912063194612197
# -0.0013146971596640356 1.9120645093093567
# -0.0010517577277795453 1.9120655610670845
# -0.0008414061820900542 1.9120664024732665
# -0.0006731249458518107 1.9120670755982123
# -0.0005384999567326076 1.912067614098169
# -0.00043079996520845043 1.9120680448981342
# -0.0003446399721127591 1.9120683895381063
# -0.00027571197769304945 1.912068665250084
# -0.00022056958241378766 1.9120688858196664
# -0.00017645566574842064 1.9120690622753322
# -0.00014116453262147388 1.912069203439865
# -0.0001129316259458335 1.912069316371491
# -9.034530078011471e-05 1.9120694067167918
# -7.227624069017224e-05 1.9120694789930326
# -5.782099243845096e-05 1.912069536814025
# -4.6256794210108865e-05 1.9120695830708192
# -3.700543518547761e-05 1.9120696200762544
# -2.9604348153355886e-05 1.9120696496806024
# -2.3683478435287952e-05 1.912069673364081
# -1.8946782923023875e-05 1.912069692310864
# -1.515742604496495e-05 1.91206970746829
# -1.2125940930474144e-05 1.9120697195942309
# -9.700752876540264e-06 1.9120697292949838
# -7.76060214491281e-06 1.912069737055586
# -6.208481845959568e-06 1.9120697432640679
# 1.9120697432640679

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
lr=LinearRegression()

# %%
lr.fit(x,y)
lr.coef_,lr.intercept_
# Out:
# (array([27.82809103]), -2.29474455867698)

# %%
np.mean(cross_val_score(lr,x,y,scoring='r2',cv=10))
# Out:
# 0.6375011587464419

# %%
class GDRegressor:
    
    def __init__(self,learning_rate,epochs):
        self.m=100
        self.b=-120
        self.lr=learning_rate
        self.epochs=epochs
        
    def fit(self,x,y):
        for i in range(self.epochs):
            loss_slope_b=-2*np.sum(y-self.m*x.ravel()-self.b)
            loss_slope_m=-2*np.sum((y-self.m*x.ravel()-self.b)*x.ravel())
            self.b=self.b-(self.lr*loss_slope_b)
            self.m=self.m-(self.lr*loss_slope_m)
        print(self.b,self.m)
        
    def predict(self,x_test):
        return self.m*x_test+self.b

# %%
gd =GDRegressor(0.001,50)

# %%
gd.fit(x,y)
# Out:
# -2.2991839308293196 27.837060471820052

# %%
gd.predict(x)
# Out:
# array([[-22.13004587],
#        [-14.46803398],
#        [-14.93031641],
#        [ 24.22481941],
#        [  4.3220791 ],
#        [ 21.67440917],
#        [ -9.07267152],
#        [  2.84916767],
#        [-22.36969544],
#        [-14.266255  ],
#        [ 53.79864004],
#        [  8.75884689],
#        [  3.48535872],
#        [ -8.76923699],
#        [-23.69550079],
#        [ 10.31541979],
#        [ 15.51330493],
#        [  7.70913832],
#        [-47.25904197],
#        [ 46.39456556],
#        [-24.26231913],
#        [-16.55078722],
#        [-28.14130775],
#        [ 57.56115677],
#        [ -8.07119002],
#        [-47.92672634],
#        [-11.72532075],
#        [-11.26615965],
#        [-15.69914914],
#        [-16.86253782],
#        [ 17.79820103],
#        [ 19.02152826],
#        [ 10.32439521],
#        [-37.41858492],
#        [-63.18204405],
#        [-35.29775901],
#        [  3.75403106],
#        [ 34.73292872],
#        [-32.56312362],
#        [ 13.35252918],
#        [-44.41234489],
#        [ -2.36568738],
#        [-10.04163129],
#        [ 10.27794346],
#        [ 30.84655074],
#        [ 23.3761659 ],
#        [ 20.3878935 ],
#        [-19.58543346],
#        [ 23.13667133],
#        [ 29.38866195],
#        [ 38.86308036],
#        [-20.42268251],
#        [-12.76369062],
#        [-23.86344212],
#        [ 11.65100525],
#        [ 35.28607828],
#        [ 17.99863937],
#        [ -4.57212324],
#        [-26.07601298],
#        [ 10.6633652 ],
#        [ -3.53801881],
#        [ -3.90071649],
#        [ 50.38919567],
#        [-31.39941033],
#        [ 13.41913163],
#        [-55.86212687],
#        [-23.56764375],
#        [  1.24456518],
#        [ -3.04442797],
#        [ -6.34144058],
#        [ 13.36881607],
#        [  6.5349329 ],
#        [ 17.49226443],
#        [ 18.68345633],
#        [-12.60212758],
#        [ 35.14449367],
#        [ 12.51953806],
#        [-29.69532713],
#        [ 35.28936573],
#        [-11.94769804],
#        [ 12.01821951],
#        [  0.51986922],
#        [-20.60253187],
#        [ 20.83078711],
#        [-11.13093595],
#        [-29.58713941],
#        [ 36.65150059],
#        [ 12.95325119],
#        [-17.06194005],
#        [ 11.36524495],
#        [  7.40900744],
#        [ 54.86959888],
#        [ 14.57811007],
#        [-13.00135576],
#        [-56.45314197],
#        [-11.06390724],
#        [ 49.18859292],
#        [-33.49080147],
#        [-11.5598996 ],
#        [-23.38445518]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((80, 1), (20, 1), (80,), (20,))

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
lr.coef_,lr.intercept_
# Out:
# (array([28.12597332]), -2.2710144261783825)

# %%
from sklearn.metrics import r2_score
y_pred_lr=lr.predict(x_test)
r2_score_lr=r2_score(y_test,y_pred_lr)
r2_score_lr
# Out:
# 0.6345158782661012

# %%
y_test.shape,y_pred_lr.shape
# Out:
# ((20,), (20,))

# %%
gd=GDRegressor(0.001,50)
gd.fit(x_train,y_train)
# Out:
# -2.3004574196824854 28.159367347119066

# %%
y_pred_gd=gd.predict(x_test)

# %%
y_test.shape,y_pred_gd.shape
# Out:
# ((20,), (20, 1))

# %%
y_pred_gd=gd.predict(x_test)
r2_score_gd=r2_score(y_test,y_pred_gd)
r2_score_gd
# Out:
# 0.6343842836315579
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
