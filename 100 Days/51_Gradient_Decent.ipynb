# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

# %%
x,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
plt.scatter(x,y)

# %%
#lets apply ols
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red')

# %%
#lets apply gradient decent
# and lets assume the starting value for intercept b=0
y_pred=((78.35 * x)+0).reshape(4)

# %%
y_pred
# Out:
# array([-55.81580837,  35.39949674,  -3.48681619,  59.05759577])

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='green',label='b=0')
plt.legend()
plt.show()

# %%
m=78.35
b=0

# %%
loss_slope=-2 * np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# -209.27763408209216

# %%
#lets take learning rate=0.1
lr=0.1
step_size=loss_slope*lr
step_size
# Out:
# -20.927763408209216

# %%
# calculating the new intercept
b=b-step_size
b
# Out:
# 20.927763408209216

# %%
y_pred1=((78.35 * x)+b).reshape(4)
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='black',label='ols')
plt.plot(x,y_pred1,color='purple',label='b={}'.format(b))
plt.plot(x,y_pred,color='black',label='b=0')
plt.legend()

# %%
#iterration 2
loss_slope=-2 * np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# -41.85552681641843

# %%
step_size=loss_slope*lr
step_size
# Out:
# -4.185552681641844

# %%
b=b-step_size
b
# Out:
# 25.11331608985106

# %%
y_pred1=((78.35 * x)+b).reshape(4)
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='black',label='ols')
plt.plot(x,y_pred1,color='purple',label='b={}'.format(b))
plt.plot(x,y_pred,color='black',label='b=0')
plt.legend()

# %%
#iteration 3
loss_slope=-2 * np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# -8.371105363283675

# %%
step_size=loss_slope*lr
step_size
# Out:
# -0.8371105363283675

# %%
b=b-step_size
b
# Out:
# 25.95042662617943

# %%
y_pred1=((78.35 * x)+b).reshape(4)
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='black',label='ols')
plt.plot(x,y_pred1,color='purple',label='b={}'.format(b))
plt.plot(x,y_pred,color='black',label='b=0')
plt.legend()

# %%
#iteration 4
loss_slope=-2 * np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# -1.674221072656735

# %%
step_size=loss_slope*lr
step_size
# Out:
# -0.16742210726567353

# %%
b=b-step_size
b
# Out:
# 26.1178487334451

# %%
y_pred1=((78.35 * x)+b).reshape(4)
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='black',label='ols')
plt.plot(x,y_pred1,color='purple',label='b={}'.format(b))
plt.plot(x,y_pred,color='black',label='b=0')
plt.legend()

# %%
b=-100
m=78.35
lr=0.1

epochs=10

for i in range(100):
    loss_slope=-2*np.sum(y-m*x.ravel()-b)
    b=b-(lr*loss_slope)
    y_pred=m*x+b
    plt.plot(x,y_pred)
plt.scatter(x,y)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [83.11009851]
# 3.4661608030066873

# %%
m=83.11009851

# %%
class GDRegressor:
    def __init__(self,learning_rate,epochs):
        self.m=36.82739982
        self.b=-120
        self.lr=learning_rate
        self.epochs=epochs
        
    def fit(self,x,y):
        #calculate the b using GD
        for i in range(self.epochs):
            loss_slope=-2*np.sum(y-self.m*x.ravel()-self.b)
            self.b=self.b-(self.lr*loss_slope)
            print(loss_slope,self.b)
        
        print(self.b)

# %%
gd=GDRegressor(0.001,100)

# %%
gd.fit(x,y)
# Out:
# -26213.799822738212 -93.78620017726179
# -20971.039858190572 -72.81516031907123
# -16776.831886552456 -56.03832843251877
# -13421.465509241963 -42.616862923276805
# -10737.172407393573 -31.879690515883233
# -8589.737925914857 -23.289952589968376
# -6871.790340731885 -16.41816224923649
# -5497.432272585508 -10.920729976650984
# -4397.945818068408 -6.522784158582576
# -3518.356654454725 -3.004427504127851
# -2814.68532356378 -0.1897421805640711
# -2251.748258851024 2.0620060782869527
# -1801.3986070808194 3.8634046853677724
# -1441.118885664656 5.304523571032428
# -1152.8951085317244 6.457418679564153
# -922.3160868253793 7.379734766389532
# -737.8528694603034 8.117587635849835
# -590.2822955682428 8.707869931418077
# -472.22583645459446 9.180095767872672
# -377.78066916367567 9.557876437036347
# -302.22453533094045 9.860100972367288
# -241.7796282647521 10.10188060063204
# -193.42370261180199 10.295304303243842
# -154.7389620894415 10.450043265333283
# -123.79116967155312 10.573834435004837
# -99.03293573724224 10.672867370742079
# -79.22634858979413 10.752093719331873
# -63.38107887183554 10.815474798203708
# -50.70486309746822 10.866179661301176
# -40.56389047797502 10.906743551779151
# -32.45111238237962 10.93919466416153
# -25.960889905903713 10.965155554067433
# -20.76871192472325 10.985924265992157
# -16.614969539778542 11.002539235531936
# -13.291975631822794 11.015831211163759
# -10.633580505458283 11.026464791669218
# -8.50686440436641 11.034971656073584
# -6.805491523493231 11.041777147597077
# -5.44439321879446 11.047221540815872
# -4.355514575035443 11.051577055390908
# -3.484411660028414 11.055061467050937
# -2.7875293280226288 11.05784899637896
# -2.2300234624180177 11.060079019841378
# -1.7840187699341925 11.061863038611312
# -1.427215015947752 11.06329025362726
# -1.1417720127582385 11.064432025640018
# -0.9134176102063094 11.065345443250225
# -0.7307340881649935 11.06607617733839
# -0.5845872705319408 11.066660764608923
# -0.467669816425456 11.067128434425348
# -0.37413585314067177 11.067502570278489
# -0.2993086825119633 11.067801878961001
# -0.23944694600984917 11.06804132590701
# -0.19155755680776565 11.068232883463818
# -0.15324604544613862 11.068386129509264
# -0.12259683635717522 11.068508726345621
# -0.09807746908549575 11.068606803814706
# -0.07846197526885135 11.068685265789975
# -0.06276958021490486 11.06874803537019
# -0.05021566417185852 11.068798251034362
# -0.040172531337447026 11.0688384235657
# -0.03213802507031005 11.068870561590769
# -0.02571042005600077 11.068896272010825
# -0.020568336045045044 11.068916840346871
# -0.016454668835606867 11.068933295015707
# -0.013163735068445703 11.068946458750776
# -0.010530988054654244 11.068956989738831
# -0.008424790443683605 11.068965414529275
# -0.006739832354995201 11.06897215436163
# -0.005391865883794367 11.068977546227513
# -0.004313492707197497 11.068981859720221
# -0.0034507941656727326 11.068985310514387
# -0.00276063533263482 11.06898807114972
# -0.0022085082660652233 11.068990279657987
# -0.0017668066126361737 11.068992046464599
# -0.0014134452899980943 11.068993459909889
# -0.0011307562321150044 11.06899459066612
# -0.0009046049857630578 11.068995495271107
# -0.0007236839885251811 11.068996218955096
# -0.0005789471907178267 11.068996797902287
# -0.000463157752633947 11.068997261060039
# -0.0003705262021753697 11.06899763158624
# -0.0002964209616749258 11.068997928007203
# -0.00023713676930015026 11.068998165143972
# -0.0001897094157925494 11.068998354853388
# -0.000151767532059921 11.06899850662092
# -0.00012141402618226493 11.068998628034945
# -9.713122069854307e-05 11.068998725166166
# -7.770497667536347e-05 11.068998802871143
# -6.216398153924274e-05 11.068998865035125
# -4.973118480222638e-05 11.06899891476631
# -3.978494795831011e-05 11.068998954551258
# -3.182795828138296e-05 11.068998986379217
# -2.5462366522788216e-05 11.068999011841584
# -2.0369893277916162e-05 11.068999032211476
# -1.6295914718966742e-05 11.06899904850739
# -1.3036731871807206e-05 11.068999061544122
# -1.0429385440602346e-05 11.068999071973508
# -8.343508412167466e-06 11.068999080317017
# -6.674806627415819e-06 11.068999086991823
# 11.068999086991823

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
lr=LinearRegression()

# %%
lr.fit(x,y)
lr.coef_,lr.intercept_
# Out:
# (array([27.82809103]), -2.29474455867698)

# %%
np.mean(cross_val_score(lr,x,y,scoring='r2',cv=10))
# Out:
# 0.6375011587464419

# %%
class GDRegressor:
    
    def __init__(self,learning_rate,epochs):
        self.m=100
        self.b=-120
        self.lr=learning_rate
        self.epochs=epochs
        
    def fit(self,x,y):
        for i in range(self.epochs):
            loss_slope_b=-2*np.sum(y-self.m*x.ravel()-self.b)
            loss_slope_m=-2*np.sum((y-self.m*x.ravel()-self.b)*x.ravel())
            self.b=self.b-(self.lr*loss_slope_b)
            self.m=self.m-(self.lr*loss_slope_m)
        print(self.b,self.m)
        
    def predict(self,x_test):
        return self.m*x_test+self.b

# %%
gd =GDRegressor(0.001,50)

# %%
gd.fit(x,y)
# Out:
# -2.2991839308293196 27.837060471820052

# %%
gd.predict(x)
# Out:
# array([[-22.13004587],
#        [-14.46803398],
#        [-14.93031641],
#        [ 24.22481941],
#        [  4.3220791 ],
#        [ 21.67440917],
#        [ -9.07267152],
#        [  2.84916767],
#        [-22.36969544],
#        [-14.266255  ],
#        [ 53.79864004],
#        [  8.75884689],
#        [  3.48535872],
#        [ -8.76923699],
#        [-23.69550079],
#        [ 10.31541979],
#        [ 15.51330493],
#        [  7.70913832],
#        [-47.25904197],
#        [ 46.39456556],
#        [-24.26231913],
#        [-16.55078722],
#        [-28.14130775],
#        [ 57.56115677],
#        [ -8.07119002],
#        [-47.92672634],
#        [-11.72532075],
#        [-11.26615965],
#        [-15.69914914],
#        [-16.86253782],
#        [ 17.79820103],
#        [ 19.02152826],
#        [ 10.32439521],
#        [-37.41858492],
#        [-63.18204405],
#        [-35.29775901],
#        [  3.75403106],
#        [ 34.73292872],
#        [-32.56312362],
#        [ 13.35252918],
#        [-44.41234489],
#        [ -2.36568738],
#        [-10.04163129],
#        [ 10.27794346],
#        [ 30.84655074],
#        [ 23.3761659 ],
#        [ 20.3878935 ],
#        [-19.58543346],
#        [ 23.13667133],
#        [ 29.38866195],
#        [ 38.86308036],
#        [-20.42268251],
#        [-12.76369062],
#        [-23.86344212],
#        [ 11.65100525],
#        [ 35.28607828],
#        [ 17.99863937],
#        [ -4.57212324],
#        [-26.07601298],
#        [ 10.6633652 ],
#        [ -3.53801881],
#        [ -3.90071649],
#        [ 50.38919567],
#        [-31.39941033],
#        [ 13.41913163],
#        [-55.86212687],
#        [-23.56764375],
#        [  1.24456518],
#        [ -3.04442797],
#        [ -6.34144058],
#        [ 13.36881607],
#        [  6.5349329 ],
#        [ 17.49226443],
#        [ 18.68345633],
#        [-12.60212758],
#        [ 35.14449367],
#        [ 12.51953806],
#        [-29.69532713],
#        [ 35.28936573],
#        [-11.94769804],
#        [ 12.01821951],
#        [  0.51986922],
#        [-20.60253187],
#        [ 20.83078711],
#        [-11.13093595],
#        [-29.58713941],
#        [ 36.65150059],
#        [ 12.95325119],
#        [-17.06194005],
#        [ 11.36524495],
#        [  7.40900744],
#        [ 54.86959888],
#        [ 14.57811007],
#        [-13.00135576],
#        [-56.45314197],
#        [-11.06390724],
#        [ 49.18859292],
#        [-33.49080147],
#        [-11.5598996 ],
#        [-23.38445518]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((80, 1), (20, 1), (80,), (20,))

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
lr.coef_,lr.intercept_
# Out:
# (array([28.12597332]), -2.2710144261783825)

# %%
from sklearn.metrics import r2_score
y_pred_lr=lr.predict(x_test)
r2_score_lr=r2_score(y_test,y_pred_lr)
r2_score_lr
# Out:
# 0.6345158782661012

# %%
y_test.shape,y_pred_lr.shape
# Out:
# ((20,), (20,))

# %%
gd=GDRegressor(0.001,50)
gd.fit(x_train,y_train)
# Out:
# -2.3004574196824854 28.159367347119066

# %%
y_pred_gd=gd.predict(x_test)

# %%
y_test.shape,y_pred_gd.shape
# Out:
# ((20,), (20, 1))

# %%
y_pred_gd=gd.predict(x_test)
r2_score_gd=r2_score(y_test,y_pred_gd)
r2_score_gd
# Out:
# 0.6343842836315579
