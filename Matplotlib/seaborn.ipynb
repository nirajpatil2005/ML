# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=tips)

# %%
sns.relplot(x='sex',y='tip',data=tips)

# %% [markdown]
# Grouping

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='day')

# %% [markdown]
# for ko=nowing sub category of group (style)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='day',style='smoker')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='tip',y='total_bill',data=tips,hue='day',style='smoker',
            size='size')

# %%
df=pd.DataFrame(np.random.randn(300,2),columns=['a','b'])
df
# Out:
#             a         b
# 0    0.100193  0.415390
# 1   -0.959215  0.196217
# 2    0.078458 -1.282904
# 3    0.958743 -0.525971
# 4    1.947356 -0.894149
# ..        ...       ...
# 295  0.163510 -0.023595
# 296  1.439110 -1.037693
# 297 -1.445184  0.583080
# 298 -0.305458  0.842320
# 299 -0.440044 -0.322049
#
# [300 rows x 2 columns]

# %%
sns.relplot(data=df,x='a',y='b',kind='line')

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#categorical data vs numerical
sns.catplot(x='day',y='tip',data=tips)

# %%
#categorical data vs numerical
sns.catplot(x='smoker',y='tip',data=tips)

# %%
import plotly.express as px
import plotly as py
import plotly.offline as iplot
df=px.data.tips()
import cufflinks as cf
cf.go_offline()
cf.set_config_file(theme='solar')
py.offline.init_notebook_mode(connected=True)
df.iplot(x='smoker',y='tip',kind='bar',xTitle='Smoker',yTitle='tip')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="bc795027-ca99-44e5-9cf9-5be65a8f9e76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Categorical Box plot

# %%
sns.catplot(x='day',y='tip',kind='box',data=tips)

# %%
sns.catplot(x='day',y='tip',kind='box',data=tips,hue='sex')

# %%
x=np.random.randn(10000)
x
# Out:
# array([-0.26579036, -0.81965432,  1.45355582, ...,  0.79776673,
#         0.09758248,  1.93148193])

# %%
sns.displot(x)

# %%
sns.distplot(x)
# Out:
# C:\Users\niraj\AppData\Local\Temp\ipykernel_198068\3746914587.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: ylabel='Density'>

# %% [markdown]
# When you take a large number of random samples of size
# 𝑛
# n from any population with a finite mean and variance, the sampling distribution of the sample mean will be approximately normally distributed, regardless of the shape of the population distribution.

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Jointplot

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'])

# %%
x=np.random.rand(1000)
sns.distplot(x)
# Out:
# C:\Users\niraj\AppData\Local\Temp\ipykernel_198068\663331315.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: ylabel='Density'>

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],kind='kde')

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],kind='hex')

# %% [markdown]
# Pair Plot---> scatter matrix

# %%
sns.pairplot(iris)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %% [markdown]
# regression plot

# %%
sns.regplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day')
