# %%
import pandas as pd

# %%
pd.read_csv("D:\\ML\\Database\\SQL\\mydb.csv")
# Out:
#    id firstname  lastname       rdate class section
# 0   1     niraj     patil  21-02-2024     A      AI
# 1   2    gaurav     patil  12-03-2024     B      DS
# 2   3     Ayush   gaikwad  23-04-2024     C    AIDS
# 3   4    Maulik  sonawane  20-01-2022     D      IT

# %%
df=pd.read_csv("customers.csv")

# %%
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.head(20)
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1       2  1Ef7b82A4CAAD10    Preston     Lozano
# 2       3  6F94879bDAfE5a6        Roy      Berry
# 3       4  5Cef8BFA16c5e3c      Linda      Olsen
# 4       5  053d585Ab6b3159     Joanna     Bender
# 5       6  2d08FB17EE273F4      Aimee      Downs
# 6       7  EA4d384DfDbBf77     Darren       Peck
# 7       8  0e04AFde9f225dE      Brett     Mullen
# 8       9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9      10  8C2811a503C7c5a   Michelle  Gallagher
# 10     11  216E205d6eBb815       Carl  Schroeder
# 11     12  CEDec94deE6d69B      Jenna     Dodson
# 12     13  e35426EbDEceaFF     Tracey       Mata
# 13     14  A08A8aF8BE9FaD4   Kristine        Cox
# 14     15  6fEaA1b7cab7B6C      Faith       Lutz
# 15     16  8cad0b4CBceaeec    Miranda    Beasley
# 16     17  a5DC21AE3a21eaA   Caroline      Foley
# 17     18  F8Aa9d6DfcBeeF8       Greg       Mata
# ...

# %%
df.tail(5)
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Creating one file from another one

# %%
file=df.tail(10)
file.to_csv("test_tail.csv")

# %%
pd.read_csv("test_tail.csv",sep="#")
# Out:
#    Unnamed: 0  Index      Customer Id First Name Last Name  \
# 0          90     91  5ef6d3eefdD43bE       Nina    Chavez
# 1          91     92  98b3aeDcC3B9FF3      Shane     Foley
# 2          92     93  aAb6AFc7AfD0fF3     Collin     Ayers
# 3          93     94  54B5B5Fe9F1B6C5     Sherry     Young
# 4          94     95  BE91A0bdcA49Bbc    Darrell   Douglas
# 5          95     96  cb8E23e48d22Eae       Karl     Greer
# 6          96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 7          97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 8          98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 9          99    100  2354a0E336A91A1   Clarence    Haynes
#
#                        Company              City          Country  \
# 0                Byrd-Campbell    Cassidychester           Bhutan
# 1                   Rocha-Hart  South Dannymouth          Hungary
# 2                Lamb-Peterson      South Lonnie         Anguilla
# ...

# %% [markdown]
# header is absent

# %%
pd.read_csv("customers.csv",sep=",",header=None)
# Out:
#         0                1           2          3   \
# 0    Index      Customer Id  First Name  Last Name
# 1        1  DD37Cf93aecA6Dc      Sheryl     Baxter
# 2        2  1Ef7b82A4CAAD10     Preston     Lozano
# 3        3  6F94879bDAfE5a6         Roy      Berry
# 4        4  5Cef8BFA16c5e3c       Linda      Olsen
# ..     ...              ...         ...        ...
# 96      96  cb8E23e48d22Eae        Karl      Greer
# 97      97  CeD220bdAaCfaDf        Lynn   Atkinson
# 98      98  28CDbC0dFe4b1Db        Fred     Guerra
# 99      99  c23d1D9EE8DEB0A      Yvonne     Farmer
# 100    100  2354a0E336A91A1    Clarence     Haynes
#
#                                   4                  5                    6   \
# 0                            Company               City              Country
# 1                    Rasmussen Group       East Leonard                Chile
# 2                        Vega-Gentry  East Jimmychester             Djibouti
# ...

# %% [markdown]
# naming the columns

# %%
pd.read_csv("customers.csv",sep=",",header=None,names=['a','b','c','d','e','f','g','h','i','j','k','l'])
# Out:
#          a                b           c          d  \
# 0    Index      Customer Id  First Name  Last Name
# 1        1  DD37Cf93aecA6Dc      Sheryl     Baxter
# 2        2  1Ef7b82A4CAAD10     Preston     Lozano
# 3        3  6F94879bDAfE5a6         Roy      Berry
# 4        4  5Cef8BFA16c5e3c       Linda      Olsen
# ..     ...              ...         ...        ...
# 96      96  cb8E23e48d22Eae        Karl      Greer
# 97      97  CeD220bdAaCfaDf        Lynn   Atkinson
# 98      98  28CDbC0dFe4b1Db        Fred     Guerra
# 99      99  c23d1D9EE8DEB0A      Yvonne     Farmer
# 100    100  2354a0E336A91A1    Clarence     Haynes
#
#                                    e                  f                    g  \
# 0                            Company               City              Country
# 1                    Rasmussen Group       East Leonard                Chile
# 2                        Vega-Gentry  East Jimmychester             Djibouti
# ...

# %% [markdown]
# skips the rows

# %%
pd.read_csv("customers.csv",sep=",",skiprows=[1,2,4,6])
# Out:
#     Index      Customer Id First Name Last Name                       Company  \
# 0       3  6F94879bDAfE5a6        Roy     Berry                 Murillo-Perry
# 1       5  053d585Ab6b3159     Joanna    Bender      Martin, Lang and Andrade
# 2       7  EA4d384DfDbBf77     Darren      Peck  Lester, Woodard and Mitchell
# 3       8  0e04AFde9f225dE      Brett    Mullen  Sanford, Davenport and Giles
# 4       9  C2dE4dEEc489ae0     Sheryl    Meyers                Browning-Simon
# ..    ...              ...        ...       ...                           ...
# 91     96  cb8E23e48d22Eae       Karl     Greer                     Carey LLC
# 92     97  CeD220bdAaCfaDf       Lynn  Atkinson         Ware, Burns and Oneal
# 93     98  28CDbC0dFe4b1Db       Fred    Guerra                 Schmitt-Jones
# 94     99  c23d1D9EE8DEB0A     Yvonne    Farmer            Fitzgerald-Harrell
# 95    100  2354a0E336A91A1   Clarence    Haynes            Le, Nash and Cross
#
# ...

# %%
pd.read_csv("customers.csv",sep=",",na_values=[1,"Sheryl","Roy"])
# Out:
#     Index      Customer Id First Name Last Name  \
# 0     NaN  DD37Cf93aecA6Dc        NaN    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        NaN     Berry
# 3     4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
df1=pd.read_csv('sales.csv')
df1
# Out:
#   transactionType  transactionId  referencedOrderId externalContactIdType  \
# 0           order            123                NaN                 email
# 1           order            234                NaN                mobile
# 2           order            456                NaN                 email
# 3           order            456                NaN                 email
# 4          refund            345              456.0                 email
# 5          refund            346              456.0                mobile
#
#     externalContactId accountCurrency transactionCurrency  \
# 0  xyz2@emailserv.com             EUR                 EUR
# 1         36301231231             EUR                 CAD
# 2   xyz@emailserv.com             EUR                 AUD
# 3   xyz@emailserv.com             EUR                 AUD
# 4   xyz@emailserv.com             EUR                 AUD
# 5         36309876987             EUR                 AUD
#
# ...

# %%
df1.dtypes
# Out:
# transactionType                    object
# transactionId                       int64
# referencedOrderId                 float64
# externalContactIdType              object
# externalContactId                  object
# accountCurrency                    object
# transactionCurrency                object
# transactionCreatedDateTime         object
# transactionLastChangedDateTime     object
# storeId                           float64
# salesChannel                       object
# productId                           int64
# quantity                            int64
# amountInAccountCurrency             int64
# amountInTransactionCurrency         int64
# customColor                        object
# dtype: object

# %%
df1.describe()
# Out:
#        transactionId  referencedOrderId    storeId   productId    quantity  \
# count       6.000000                2.0   5.000000    6.000000    6.000000
# mean      326.666667              456.0  11.800000  211.166667   40.500000
# std       129.793169                0.0   0.447214  194.621085   62.911843
# min       123.000000              456.0  11.000000   23.000000   -2.000000
# 25%       261.750000              456.0  12.000000   45.000000   -0.500000
# 50%       345.500000              456.0  12.000000  166.500000    3.000000
# 75%       428.500000              456.0  12.000000  388.500000   76.250000
# max       456.000000              456.0  12.000000  444.000000  140.000000
#
#        amountInAccountCurrency  amountInTransactionCurrency
# count                 6.000000                     6.000000
# mean                365.833333                   547.000000
# std                 540.707099                   823.080798
# ...

# %% [markdown]
# For removing index column

# %%
df1.to_csv("result.csv",index=False)

# %% [markdown]
# for removing column name

# %%
df1.to_csv("result.csv",index=False,header=None)

# %% [markdown]
# for using your own seprartor

# %%
df1.to_csv("result.csv",index=False,header=None,sep="*")

# %% [markdown]
# own column selection

# %%
df1.to_csv("result1.csv",index=False,header=None,sep="*",columns=["transactionId","productId","quantity"])

# %%
df1.tail()
# Out:
#   transactionType  transactionId  referencedOrderId externalContactIdType  \
# 1           order            234                NaN                mobile
# 2           order            456                NaN                 email
# 3           order            456                NaN                 email
# 4          refund            345              456.0                 email
# 5          refund            346              456.0                mobile
#
#    externalContactId accountCurrency transactionCurrency  \
# 1        36301231231             EUR                 CAD
# 2  xyz@emailserv.com             EUR                 AUD
# 3  xyz@emailserv.com             EUR                 AUD
# 4  xyz@emailserv.com             EUR                 AUD
# 5        36309876987             EUR                 AUD
#
#   transactionCreatedDateTime transactionLastChangedDateTime  storeId  \
# 1   2023-07-21T12:18:51.545Z       2023-07-22T12:18:51.545Z     11.0
# ...

# %%
df1.columns
# Out:
# Index(['transactionType', 'transactionId', 'referencedOrderId',
#        'externalContactIdType', 'externalContactId', 'accountCurrency',
#        'transactionCurrency', 'transactionCreatedDateTime',
#        'transactionLastChangedDateTime', 'storeId', 'salesChannel',
#        'productId', 'quantity', 'amountInAccountCurrency',
#        'amountInTransactionCurrency', 'customColor'],
#       dtype='object')

# %%
df1['transactionType']
# Out:
# 0     order
# 1     order
# 2     order
# 3     order
# 4    refund
# 5    refund
# Name: transactionType, dtype: object

# %%
type(df1['transactionType'])
# Out:
# pandas.core.series.Series

# %%
df1[['transactionType']]
# Out:
#   transactionType
# 0           order
# 1           order
# 2           order
# 3           order
# 4          refund
# 5          refund

# %%
type(df1[['transactionType']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1[["transactionType","quantity","amountInAccountCurrency"]]
# Out:
#   transactionType  quantity  amountInAccountCurrency
# 0           order         1                      120
# 1           order         5                      200
# 2           order       100                      500
# 3           order       140                     1400
# 4          refund        -1                       -5
# 5          refund        -2                      -20

# %%
pd.read_excel("Finance.xlsx")
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df2=pd.read_excel("Finance.xlsx")

# %%
df2.dtypes
# Out:
# Segment                        object
# Country                        object
# Product                        object
# Discount Band                  object
# Units Sold                    float64
# Manufacturing Price             int64
# Sale Price                      int64
# Gross Sales                   float64
# Discounts                     float64
#  Sales                        float64
# COGS                          float64
# Profit                        float64
# Date                   datetime64[ns]
# Month Number                    int64
# Month Name                     object
# Year                            int64
# dtype: object

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.8 MB 1.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.0/3.8 MB 1.5 MB/s eta 0:00:02
#    ------------- -------------------------- 1.3/3.8 MB 1.6 MB/s eta 0:00:02
#    ------------------- -------------------- 1.8/3.8 MB 1.6 MB/s eta 0:00:02
#    ------------------- -------------------- 1.8/3.8 MB 1.6 MB/s eta 0:00:02
#    --------------------- ------------------ 2.1/3.8 MB 1.4 MB/s eta 0:00:02
#    ------------------------ --------------- 2.4/3.8 MB 1.4 MB/s eta 0:00:02
#    --------------------------- ------------ 2.6/3.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 1.3 MB/s eta 0:00:01
# ...

# %%
pd.read_html("https://www.espncricinfo.com/records/year/batting-most-runs-career/2024-2024/combined-test-odi-and-t20i-records-11")
# Out:
# [                Player       Span  Mat  Inns NO  Runs    HS    Ave    BF  \
#  0      BKG Mendis (SL)  2024-2024   48    55  5  1860   143  37.20  2040
#  1    YBK Jaiswal (IND)  2024-2024   23    37  3  1771  214*  52.08  2301
#  2      P Nissanka (SL)  2024-2024   37    42  4  1696  210*  44.63  1600
#  3       HC Brook (ENG)  2024-2024   27    31  4  1575   317  58.33  1646
#  4        JE Root (ENG)  2024-2024   17    31  3  1556   262  55.57  2455
#  ..                 ...        ...  ...   ... ..   ...   ...    ...   ...
#  145      N Pooran (WI)  2024-2024   21    20  2   464    98  25.77   326
#  146   JC Buttler (ENG)  2024-2024   15    13  2   462    84  42.00   281
#  147    J Liyanage (SL)  2024-2024   18    13  3   462  101*  46.20   567
#  148       E Lewis (WI)  2024-2024   14    14  2   462  102*  38.50   363
#  149   RR Patel (KENYA)  2024-2024   18    16  2   460   120  32.85   307
#
#           SR 100  50  0   4s  6s
#  0     91.17   2  11  3  200  37
# ...

# %%
df3=pd.read_html("https://www.espncricinfo.com/records/year/batting-most-runs-career/2024-2024/combined-test-odi-and-t20i-records-11")

# %%
type(df3)
# Out:
# list

# %%
len(df3)
# Out:
# 1

# %%
df3[0]
# Out:
#                 Player       Span  Mat  Inns NO  Runs    HS    Ave    BF  \
# 0      BKG Mendis (SL)  2024-2024   48    55  5  1860   143  37.20  2040
# 1    YBK Jaiswal (IND)  2024-2024   23    37  3  1771  214*  52.08  2301
# 2      P Nissanka (SL)  2024-2024   37    42  4  1696  210*  44.63  1600
# 3       HC Brook (ENG)  2024-2024   27    31  4  1575   317  58.33  1646
# 4        JE Root (ENG)  2024-2024   17    31  3  1556   262  55.57  2455
# ..                 ...        ...  ...   ... ..   ...   ...    ...   ...
# 145      N Pooran (WI)  2024-2024   21    20  2   464    98  25.77   326
# 146   JC Buttler (ENG)  2024-2024   15    13  2   462    84  42.00   281
# 147    J Liyanage (SL)  2024-2024   18    13  3   462  101*  46.20   567
# 148       E Lewis (WI)  2024-2024   14    14  2   462  102*  38.50   363
# 149   RR Patel (KENYA)  2024-2024   18    16  2   460   120  32.85   307
#
#          SR 100  50  0   4s  6s
# 0     91.17   2  11  3  200  37
# ...

# %%
df3[0].to_csv("mostruns.csv")

# %%
pd.read_csv("mostruns.csv")
# Out:
#      Unnamed: 0             Player       Span  Mat  Inns NO  Runs    HS  \
# 0             0    BKG Mendis (SL)  2024-2024   48    55  5  1860   143
# 1             1  YBK Jaiswal (IND)  2024-2024   23    37  3  1771  214*
# 2             2    P Nissanka (SL)  2024-2024   37    42  4  1696  210*
# 3             3     HC Brook (ENG)  2024-2024   27    31  4  1575   317
# 4             4      JE Root (ENG)  2024-2024   17    31  3  1556   262
# ..          ...                ...        ...  ...   ... ..   ...   ...
# 145         145      N Pooran (WI)  2024-2024   21    20  2   464    98
# 146         146   JC Buttler (ENG)  2024-2024   15    13  2   462    84
# 147         147    J Liyanage (SL)  2024-2024   18    13  3   462  101*
# 148         148       E Lewis (WI)  2024-2024   14    14  2   462  102*
# 149         149   RR Patel (KENYA)  2024-2024   18    16  2   460   120
#
#        Ave    BF      SR 100  50  0   4s  6s
# 0    37.20  2040   91.17   2  11  3  200  37
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """
{
    "name": "sudh",
    "phone": 1234567890,
    "com": ["ineuron", "HUL", "HP", "dell", "EV"]
}
"""

# %%
import json
j=json.loads(s)
j
# Out:
# {'name': 'sudh',
#  'phone': 1234567890,
#  'com': ['ineuron', 'HUL', 'HP', 'dell', 'EV']}

# %%
pd.DataFrame(j)
# Out:
#    name       phone      com
# 0  sudh  1234567890  ineuron
# 1  sudh  1234567890      HUL
# 2  sudh  1234567890       HP
# 3  sudh  1234567890     dell
# 4  sudh  1234567890       EV

# %%
d = """
{
    "name":["sudh","niraj","shubh","raj","shiv"], 
    "phone": 1234567890,
    "com": ["ineuron", "HUL", "HP", "dell", "EV"]
}
"""
import json
j=json.loads(d)
pd.DataFrame(j)
# Out:
#     name       phone      com
# 0   sudh  1234567890  ineuron
# 1  niraj  1234567890      HUL
# 2  shubh  1234567890       HP
# 3    raj  1234567890     dell
# 4   shiv  1234567890       EV

# %%
pd.DataFrame(j,columns=['com'])
# Out:
#        com
# 0  ineuron
# 1      HUL
# 2       HP
# 3     dell
# 4       EV

# %%
import requests,json
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
op=res.json()
op
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60637',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60637/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60637/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60637/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/60637',
#   'id': 2764723015,
#   'node_id': 'PR_kwDOAA0YD86Gg1Zt',
#   'number': 60637,
#   'title': 'TST(string dtype): Resolve xfail for interpolate',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
# ...

# %%
op[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60637',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60637/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60637/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60637/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/60637',
#  'id': 2764723015,
#  'node_id': 'PR_kwDOAA0YD86Gg1Zt',
#  'number': 60637,
#  'title': 'TST(string dtype): Resolve xfail for interpolate',
#  'user': {'login': 'rhshadrach',
#   'id': 45562402,
#   'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rhshadrach',
#   'html_url': 'https://github.com/rhshadrach',
#   'followers_url': 'https://api.github.com/users/rhshadrach/followers',
# ...

# %%
op[0]['title']
# Out:
# 'TST(string dtype): Resolve xfail for interpolate'

# %%
for i in range(len(op)):
    print(op[i]['title'])
# Out:
# TST(string dtype): Resolve xfail for interpolate
# TST(string dtype): Resolve xfail with apply returning an ndarray
# TST(string dtype): Resolve xfail for corrwith
# TST(string dtype): Remove xfail for combine_first
# ENH: Implement cum* methods for PyArrow strings
# DOC: Comparing .loc/.iloc to tuples and chained indexing
# Implement first-class List type
# TST(string dtype): Resolve HDF5 xfails in test_round_trip.py
# TST(string dtype): Resolve HDF5 xfails in test_put.py
# Update timestamps.pyx
# [WIP] `df.apply`: add support for `engine='bodo'`
# ENH: native support for universal_pathlib (upath) IO
# ENH: RST support
# ENH: Make print_thing respect display.precision for Real numbers
# DOC: Adding a Persian version of Pandas Cheat Sheet
# BUG: Segfault on `np.maximum(series, ...)`
# to_sql doesn't seem to allow upload of df with some columns when the target table has a calculated column
# DOC: Add Hugging Face Hub access
# ...

# %%
pd.DataFrame(op,columns=['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
cs=pd.DataFrame(op)
cs.to_csv("git.csv")

# %%
op[0]['user']
# Out:
# {'login': 'rhshadrach',
#  'id': 45562402,
#  'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/rhshadrach',
#  'html_url': 'https://github.com/rhshadrach',
#  'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#  'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#  'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#  'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#  'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#  'type': 'User',
# ...

# %%
li=[]
for i in range(len(op)):
    li.append(op[i]['user'])
pd.DataFrame(li)
# Out:
#                login         id               node_id  \
# 0         rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 1         rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 2         rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 3         rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4         rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 5         johnasiano   54973763  MDQ6VXNlcjU0OTczNzYz
# 6            WillAyd     609873  MDQ6VXNlcjYwOTg3Mw==
# 7         rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 8         rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 9         johnasiano   54973763  MDQ6VXNlcjU0OTczNzYz
# 10  scott-routledge2  171585127          U_kgDOCjouZw
# 11            zkurtz    4934167  MDQ6VXNlcjQ5MzQxNjc=
# 12             R5dan  167037995          U_kgDOCfTMKw
# 13       aydinomer00  109145643          U_kgDOBoFuKw
# 14        HasssanRad  115450900          U_kgDOBuGkFA
# 15             ssche    7367411  MDQ6VXNlcjczNjc0MTE=
# ...

# %%
data=pd.DataFrame.from_records(op['user'])
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 data=pd.DataFrame.from_records(op['user'])
#       2 data.head()
#
# TypeError: list indices must be integers or slices, not str

# %%
json_data=pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data=pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#         login        id               node_id  \
# 0  rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 1  rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 2  rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 3  rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4  rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/455624...
# 1  https://avatars.githubusercontent.com/u/455624...
# 2  https://avatars.githubusercontent.com/u/455624...
# 3  https://avatars.githubusercontent.com/u/455624...
# 4  https://avatars.githubusercontent.com/u/455624...
#
#                                        url                       html_url  \
# 0  https://api.github.com/users/rhshadrach  https://github.com/rhshadrach
# 1  https://api.github.com/users/rhshadrach  https://github.com/rhshadrach
# 2  https://api.github.com/users/rhshadrach  https://github.com/rhshadrach
# ...

# %% [markdown]
# Pickle file format

# %%
import pandas as pd,requests

# %%
form_file=pd.read_csv("mostruns.csv")

# %%
form_file.to_pickle("pickle")

# %%
pwd()
# Out:
# 'd:\\ML\\Pandas'

# %%
pd.to_pickle("D:\\ML\\Pandas\\pickle")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pd.to_pickle("D:\\ML\\Pandas\\pickle")
#
# TypeError: to_pickle() missing 1 required positional argument: 'filepath_or_buffer'

# %%
form_file
# Out:
#      Unnamed: 0             Player       Span  Mat  Inns NO  Runs    HS  \
# 0             0    BKG Mendis (SL)  2024-2024   48    55  5  1860   143
# 1             1  YBK Jaiswal (IND)  2024-2024   23    37  3  1771  214*
# 2             2    P Nissanka (SL)  2024-2024   37    42  4  1696  210*
# 3             3     HC Brook (ENG)  2024-2024   27    31  4  1575   317
# 4             4      JE Root (ENG)  2024-2024   17    31  3  1556   262
# ..          ...                ...        ...  ...   ... ..   ...   ...
# 145         145      N Pooran (WI)  2024-2024   21    20  2   464    98
# 146         146   JC Buttler (ENG)  2024-2024   15    13  2   462    84
# 147         147    J Liyanage (SL)  2024-2024   18    13  3   462  101*
# 148         148       E Lewis (WI)  2024-2024   14    14  2   462  102*
# 149         149   RR Patel (KENYA)  2024-2024   18    16  2   460   120
#
#        Ave    BF      SR 100  50  0   4s  6s
# 0    37.20  2040   91.17   2  11  3  200  37
# ...

# %%
pip install tables
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
h5_data=pd.HDFStore('test.h5')

# %%
h5_data['obj1'] =form_file

# %%
h5_data['obj1']
# Out:
#      Unnamed: 0             Player       Span  Mat  Inns NO  Runs    HS  \
# 0             0    BKG Mendis (SL)  2024-2024   48    55  5  1860   143
# 1             1  YBK Jaiswal (IND)  2024-2024   23    37  3  1771  214*
# 2             2    P Nissanka (SL)  2024-2024   37    42  4  1696  210*
# 3             3     HC Brook (ENG)  2024-2024   27    31  4  1575   317
# 4             4      JE Root (ENG)  2024-2024   17    31  3  1556   262
# ..          ...                ...        ...  ...   ... ..   ...   ...
# 145         145      N Pooran (WI)  2024-2024   21    20  2   464    98
# 146         146   JC Buttler (ENG)  2024-2024   15    13  2   462    84
# 147         147    J Liyanage (SL)  2024-2024   18    13  3   462  101*
# 148         148       E Lewis (WI)  2024-2024   14    14  2   462  102*
# 149         149   RR Patel (KENYA)  2024-2024   18    16  2   460   120
#
#        Ave    BF      SR 100  50  0   4s  6s
# 0    37.20  2040   91.17   2  11  3  200  37
# ...

# %%
h5_data.put('obj2',form_file,format='table')

# %%
h5_data.select('obj2',where=['index >=10 and index <=15'])
# Out:
#     Unnamed: 0                 Player       Span  Mat  Inns NO  Runs    HS  \
# 10          10     Shubman Gill (IND)  2024-2024   23    33  3  1189  119*
# 11          11          T Stubbs (SA)  2024-2024   33    38  7  1174   122
# 12          12       Babar Azam (PAK)  2024-2024   35    39  3  1168    75
# 13          13        RG Sharma (IND)  2024-2024   28    40  3  1154   131
# 14          14     KS Williamson (NZ)  2024-2024   15    23  3  1124   156
# 15          15  Muhammad Waseem (UAE)  2024-2024   37    37  3  1110   100
#
#       Ave    BF      SR 100 50  0   4s  6s
# 10  39.63  1686   70.52   3  5  3  127  24
# 11  37.87  1562   75.16   3  3  2   95  29
# 12  32.44  1273   91.75   -  9  3  128  21
# 13  31.18  1329   86.83   3  7  3  131  42
# 14  56.20  1950   57.64   4  5  1  132   7
# 15  32.64   873  127.14   1  8  4   83  61

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df1=df[df.dtypes[df.dtypes=='object'].index]

# %%
df1
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df1.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes[df.dtypes=='float64'].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
df3=df[df.dtypes[df.dtypes=='float64'].index]
df3
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Name',"Age"]]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df[df.dtypes[df.dtypes=='float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df[["Name"]]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
type(df[["Name"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df["Name"][5:10:1]
# Out:
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df['Ticket'][5:16]
# Out:
# 5        330877
# 6         17463
# 7        349909
# 8        347742
# 9        237736
# 10      PP 9549
# 11       113783
# 12    A/5. 2151
# 13       347082
# 14       350406
# 15       248706
# Name: Ticket, dtype: object

# %%
sorted(df['Ticket'][5:16])
# Out:
# ['113783',
#  '17463',
#  '237736',
#  '248706',
#  '330877',
#  '347082',
#  '347742',
#  '349909',
#  '350406',
#  'A/5. 2151',
#  'PP 9549']

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in df.columns:
    print(i,end=" ")
# Out:
# PassengerId Survived Pclass Name Sex Age SibSp Parch Ticket Fare Cabin Embarked

# %%
df['niraj']="Patil"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['niraj']=df['PassengerId']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
[df['Cabin'].isnull()==True]
# Out:
# [0       True
#  1      False
#  2       True
#  3      False
#  4       True
#         ...
#  886     True
#  887    False
#  888     True
#  889    False
#  890     True
#  Name: Cabin, Length: 891, dtype: bool]

# %%
ser=df['Cabin'][df['Cabin'].isnull()==False]

# %%
ser.index
# Out:
# Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#        ...
#        849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#       dtype='int64', length=204)

# %%
df.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[[1,6,5,4,7]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 6            7         0       1
# 5            6         0       3
# 4            5         0       3
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 4                           Allen, Mr. William Henry    male  35.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch    Ticket     Fare Cabin Embarked  niraj
# 1      0  PC 17599  71.2833   C85        C      2
# 6      0     17463  51.8625   E46        S      7
# 5      0    330877   8.4583   NaN        Q      6
# 4      0    373450   8.0500   NaN        S      5
# 7      1    349909  21.0750   NaN        S      8

# %%
df.iloc[df['Cabin'][df['Cabin'].isnull()==True].index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.iloc[df['Fare'][df['Fare'].isnull()==False].index]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare']==max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df[['Name','Fare']][df['Fare']==max(df['Fare'])]
# Out:
#                                    Name      Fare
# 258                    Ward, Miss. Anna  512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  512.3292
# 737              Lesurer, Mr. Gustave J  512.3292

# %%
df['new column']=df['Name']+str(df['Age'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
